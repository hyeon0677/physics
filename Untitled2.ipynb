# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeon0677/physics/blob/20250331/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 첫 번째 벡터 입력 받기

x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))

y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))



# 두 번째 벡터 입력 받기

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))

y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))



# 벡터의 합 계산

sum_x = x1 + x2

sum_y = y1 + y2



# 벡터의 내적 계산 (dot product)

dot_product = x1 * x2 + y1 * y2



# 벡터의 외적 계산 (cross product)

# 2차원 벡터의 외적은 스칼라 값으로, z축 방향의 크기를 나타냅니다

cross_product = x1 * y2 - y1 * x2



# 결과 출력

print("\n벡터 1:", x1, "i +", y1, "j")

print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")

print("벡터의 내적:", dot_product)

print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 7
# 첫 번째 벡터의 y 성분을 입력하세요: 8
# 두 번째 벡터의 x 성분을 입력하세요: 3
# 두 번째 벡터의 y 성분을 입력하세요: 9
#
# 벡터 1: 7.0 i + 8.0 j
# 벡터 2: 3.0 i + 9.0 j
#
# 벡터의 합: 10.0 i + 17.0 j
# 벡터의 내적: 93.0
# 벡터의 외적: 39.0

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
z1 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))
z2 = float(input("두 번째 벡터의 z 성분을 입력하세요: "))

# 벡터의 합 계산
sum_x = x1 + x2
sum_y = y1 + y2
sum_z = z1 + z2

# 내적 계산 (dot product)
dot_product = x1 * x2 + y1 * y2 + z1 * z2

# 외적 계산 (cross product)
cross_x = y1 * z2 - z1 * y2
cross_y = z1 * x2 - x1 * z2
cross_z = x1 * y2 - y1 * x2

# 결과 출력
print("\n벡터 1:", x1, "i +", y1, "j +", z1, "k")
print("벡터 2:", x2, "i +", y2, "j +", z2, "k")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j +", sum_z, "k")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_x, "i +", cross_y, "j +", cross_z, "k")
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 7
# 첫 번째 벡터의 y 성분을 입력하세요: 8
# 첫 번째 벡터의 z 성분을 입력하세요: 7
# 두 번째 벡터의 x 성분을 입력하세요: 3
# 두 번째 벡터의 y 성분을 입력하세요: 9
# 두 번째 벡터의 z 성분을 입력하세요: 7
#
# 벡터 1: 7.0 i + 8.0 j + 7.0 k
# 벡터 2: 3.0 i + 9.0 j + 7.0 k
#
# 벡터의 합: 10.0 i + 17.0 j + 14.0 k
# 벡터의 내적: 142.0
# 벡터의 외적: -7.0 i + -28.0 j + 39.0 k
